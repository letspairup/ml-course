# %%
import numpy as np
import matplotlib.pyplot as plt

N=12
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)

type(x)
print(f"x is {x}")
colors
# Out:
# x is [0.84551541 0.33510807 0.49188382 0.01619698 0.79569133 0.41891136
#  0.51879059 0.27801269 0.71422847 0.69501471 0.51763453 0.76482232]
# array([0.03864047, 0.19161696, 0.39637835, 0.63924753, 0.41195065,
#        0.30865804, 0.42523055, 0.5078286 , 0.80465544, 0.00612601,
#        0.67781683, 0.83138519])

# %%
area = np.pi * (15*np.random.rand(N))**2

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()
